# %% [markdown]
# <a href="https://colab.research.google.com/github/Levyashin21/Olympicsdatavis/blob/main/Olympics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline

# %%
region=pd.read_csv('/content/noc_regions.csv')

# %%
ath=pd.read_csv('/content/athlete_events.csv')

# %%
ath.head()
# Out:
#    ID                      Name  ...                             Event  Medal
# 0   1                 A Dijiang  ...       Basketball Men's Basketball    NaN
# 1   2                  A Lamusi  ...      Judo Men's Extra-Lightweight    NaN
# 2   3       Gunnar Nielsen Aaby  ...           Football Men's Football    NaN
# 3   4      Edgar Lindenau Aabye  ...       Tug-Of-War Men's Tug-Of-War   Gold
# 4   5  Christine Jacoba Aaftink  ...  Speed Skating Women's 500 metres    NaN
#
# [5 rows x 15 columns]

# %%
region.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
athlete_fulldf=ath.merge(region,how='left',on='NOC')
athlete_fulldf.head()
# Out:
#    ID                      Name Sex  ...  Medal       region  notes
# 0   1                 A Dijiang   M  ...    NaN        China    NaN
# 1   2                  A Lamusi   M  ...    NaN        China    NaN
# 2   3       Gunnar Nielsen Aaby   M  ...    NaN      Denmark    NaN
# 3   4      Edgar Lindenau Aabye   M  ...   Gold      Denmark    NaN
# 4   5  Christine Jacoba Aaftink   F  ...    NaN  Netherlands    NaN
#
# [5 rows x 17 columns]

# %%
athlete_fulldf.shape
# Out:
# (271116, 17)

# %% [markdown]
# Changing column name

# %%
athlete_fulldf.rename(columns={'region':'Region','notes':'Notes'},inplace=True)
athlete_fulldf.head()
# Out:
#    ID                      Name Sex  ...  Medal       Region  Notes
# 0   1                 A Dijiang   M  ...    NaN        China    NaN
# 1   2                  A Lamusi   M  ...    NaN        China    NaN
# 2   3       Gunnar Nielsen Aaby   M  ...    NaN      Denmark    NaN
# 3   4      Edgar Lindenau Aabye   M  ...   Gold      Denmark    NaN
# 4   5  Christine Jacoba Aaftink   F  ...    NaN  Netherlands    NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# column data type information

# %%
athlete_fulldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
athlete_fulldf.describe()
# Out:
#                   ID            Age  ...         Weight           Year
# count  271116.000000  261642.000000  ...  208241.000000  271116.000000
# mean    68248.954396      25.556898  ...      70.702393    1978.378480
# std     39022.286345       6.393561  ...      14.348020      29.877632
# min         1.000000      10.000000  ...      25.000000    1896.000000
# 25%     34643.000000      21.000000  ...      60.000000    1960.000000
# 50%     68205.000000      24.000000  ...      70.000000    1988.000000
# 75%    102097.250000      28.000000  ...      79.000000    2002.000000
# max    135571.000000      97.000000  ...     214.000000    2016.000000
#
# [8 rows x 5 columns]

# %%
nun_value=athlete_fulldf.isna()
nun_column=nun_value.any()
nun_column
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
athlete_fulldf.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
athlete_fulldf.query('Team == "India"').head(5)
# Out:
#       ID                             Name Sex  ...  Medal  region  notes
# 505  281                   S. Abdul Hamid   M  ...    NaN   India    NaN
# 506  281                   S. Abdul Hamid   M  ...    NaN   India    NaN
# 895  512  Shiny Kurisingal Abraham-Wilson   F  ...    NaN   India    NaN
# 896  512  Shiny Kurisingal Abraham-Wilson   F  ...    NaN   India    NaN
# 897  512  Shiny Kurisingal Abraham-Wilson   F  ...    NaN   India    NaN
#
# [5 rows x 17 columns]

# %%
athlete_fulldf.query('Team == "China"').head(20)
# Out:
#          ID           Name Sex  ...   Medal  region  notes
# 0         1      A Dijiang   M  ...     NaN   China    NaN
# 1         2       A Lamusi   M  ...     NaN   China    NaN
# 1072    602  Abudoureheman   M  ...     NaN   China    NaN
# 2611   1463      Ai Linuer   M  ...     NaN   China    NaN
# 2612   1464      Ai Yanhan   F  ...     NaN   China    NaN
# 2613   1464      Ai Yanhan   F  ...     NaN   China    NaN
# 6427   3605    An Weijiang   M  ...     NaN   China    NaN
# 6428   3605    An Weijiang   M  ...     NaN   China    NaN
# 6433   3610      An Yulong   M  ...  Silver   China    NaN
# 6434   3610      An Yulong   M  ...     NaN   China    NaN
# 6435   3610      An Yulong   M  ...  Bronze   China    NaN
# 6436   3610      An Yulong   M  ...  Bronze   China    NaN
# 6437   3611    An Zhongxin   F  ...  Silver   China    NaN
# 6438   3611    An Zhongxin   F  ...     NaN   China    NaN
# 8423   4639   Ao Changrong   M  ...     NaN   China    NaN
# ...

# %% [markdown]
# Top 10 country with no of member participating by each country

# %%
top_10=athlete_fulldf.Team.value_counts().sort_values(ascending=False).head(10)
top_10
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
plt.figure(figsize=(11,6))
plt.title('overall team participated')
sns.barplot(x=top_10.index,y=top_10, palette='Set2');

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Age')
plt.ylabel('Number of participants')
plt.hist(athlete_fulldf.Age, bins=np.arange(10,80,2),color='orange',edgecolor='black');

# %%
summer_sports=athlete_fulldf[athlete_fulldf.Season== 'Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
winter_sports=athlete_fulldf[athlete_fulldf.Season== 'Winter'].Sport.unique()
winter_sports
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
summer_sports=athlete_fulldf[athlete_fulldf.Season== 'Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
gender_counts=athlete_fulldf.Sex.value_counts()
gender_counts
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %% [markdown]
# Pie graph of gender distribution

# %%
plt.figure(figsize=(12,6))
plt.title('Gender distribution')
plt.pie(gender_counts,labels=gender_counts.index,autopct='%1.1f%%',startangle=150,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0d16581610>,
# ...
#  [Text(0.20089640434146097, -1.081499253223354, 'M'),
#   Text(-0.2008963030841931, 1.081499272032628, 'F')],
#  [Text(0.10957985691352415, -0.5899086835763748, '72.5%'),
#   Text(-0.10957980168228713, 0.5899086938359788, '27.5%')])

# %% [markdown]
# No of medals

# %%
athlete_fulldf.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %% [markdown]
# Gold metal atheletes

# %%
goldmedal=athlete_fulldf[athlete_fulldf.Medal=='Gold']
goldmedal.head()
# Out:
#     ID                     Name Sex  ...  Medal   Region  Notes
# 3    4     Edgar Lindenau Aabye   M  ...   Gold  Denmark    NaN
# 42  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 44  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 48  17  Paavo Johannes Aaltonen   M  ...   Gold  Finland    NaN
# 60  20       Kjetil Andr Aamodt   M  ...   Gold   Norway    NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# gold medal at age greater 58

# %%
goldmedal=goldmedal[np.isfinite(goldmedal['Age'])]
goldmedal['ID'][goldmedal['Age']> 58].count()
# Out:
# 12

# %% [markdown]
# gold medal in which sports above 60 participants

# %%
goldmedal['Name'][goldmedal['Age']> 58]
# Out:
# 63622                       Everard Coenraad Endt
# 104003                       Isaac Lazarus Israls
# 105199                            Charles Jacobus
# 159298                     Joshua Kearney Millner
# 173097             William Herbert "Bill" Northam
# 190952    Lida Peyton "Eliza" Pollock (McMillen-)
# 226374               Galen Carter "G. C." Spencer
# 233386                          Oscar Gomer Swahn
# 233387                          Oscar Gomer Swahn
# 233390                          Oscar Gomer Swahn
# 261102                    Robert W. Williams, Jr.
# 261675                              Walter Winans
# Name: Name, dtype: object

# %%
sport_event=goldmedal['Sport'][goldmedal['Age']> 58]
sport_event
# Out:
# 63622              Sailing
# 104003    Art Competitions
# 105199               Roque
# 159298            Shooting
# 173097             Sailing
# 190952             Archery
# 226374             Archery
# 233386            Shooting
# 233387            Shooting
# 233390            Shooting
# 261102             Archery
# 261675    Art Competitions
# Name: Sport, dtype: object

# %%
plt.figure(figsize=(10,5))
plt.tight_layout()
sns.countplot(sport_event)
plt.title('gold medal at age greater 58')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'gold medal at age greater 58')

# %% [markdown]
# Gold medals by top 10 country

# %%
goldmedal.Region.value_counts().reset_index(name='Medals').head(10)
# Out:
#      index  Medals
# 0      USA    2627
# 1   Russia    1599
# 2  Germany    1293
# 3       UK     657
# 4    Italy     567
# 5   France     491
# 6   Sweden     479
# 7   Canada     461
# 8  Hungary     432
# 9   Norway     378

# %%
top10=goldmedal.Region.value_counts().reset_index(name='Medals').head(10)
g=sns.catplot(x='index',y='Medals',data=top10 , height=12,kind="bar",palette="flare")
g.set_xlabels("top 10 countries")
g.despine(left=True)
g.set_ylabels("Number of medals")
plt.title("Gold medals per country")
# Out:
# Text(0.5, 1.0, 'Gold medals per country')

# %%
non_nullmedals=athlete_fulldf[(athlete_fulldf['Height'].notnull()) & (athlete_fulldf['Sport'].notnull())]

# %%
plt.figure(figsize=(24,12))
axis= sns.scatterplot(x="Height",y="Sport",data=non_nullmedals,hue="Sex")
plt.title('Height vs sport of olympic Medalists')
# Out:
# Text(0.5, 1.0, 'Height vs sport of olympic Medalists')

# %%
nonnullmedals=athlete_fulldf[(athlete_fulldf['Height'].notnull()) & (athlete_fulldf['Weight'].notnull())]
plt.figure(figsize=(12,6))
axis= sns.scatterplot(x="Height",y="Weight",data=nonnullmedals,hue="Sex")
plt.title('Height vs weight of olympic Medalists')
# Out:
# Text(0.5, 1.0, 'Height vs weight of olympic Medalists')
